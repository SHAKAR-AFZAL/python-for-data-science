# %%
print("HELLO WORLD")
# Out:
# HELLO WORLD

# %%
a=73
A="MIAN SAAB"
print("a:",a)
print("A:",A)
# Out:
# a: 73
# A: MIAN SAAB

# %%
print("NAME: MIAN SHAKAR AFZAL")
print("REG NO: F23605073")
print("BATCH: CS-23-B")
# Out:
# NAME: MIAN SHAKAR AFZAL
# REG NO: F23605073
# BATCH: CS-23-B

# %%
a=b=c=73
print(a)
print(b)
print(c)
# Out:
# 73
# 73
# 73

# %%
a,b,c=1,2,3
print(a)
print(b)
print(c)
# Out:
# 1
# 2
# 3

# %%
# INPUT YOUR NAME AND ALL NECESSARY DETAILS
print("NAME: MIAN SHAKAR AFZAL")
print("REG NO: F23605073")
# Out:
# NAME: MIAN SHAKAR AFZAL
# REG NO: F23605073

# %%
# Write A Program In Which Take Two Numbers From Users & Print Their Their Sum
print("SUM OF THE THE TWO NUMBERS")
n1=(input("Number 1:"))
n2=(input("Number 2:"))
Sum=int(n1)+int(n2)
print(Sum)
print(type(n1))
# Out:
# SUM OF THE THE TWO NUMBERS
# Number 1:25
# Number 2:75
# 100
# <class 'str'>

# %%
# LOGICAL BOOLEAN PROGRAM
a=True+5
print("a:",a)
b=10+False
print("b:",b)
sum=a+b
print("Sum:",sum)
# Out:
# a: 6
# b: 10
# Sum: 16

# %%
#Type CASTING  integer to Float
num = 10
print("Original Value:", num)
print("Original Type:", type(num))
new_num = float(num)
print("After Type Casting:", new_num)
print("New Type:", type(new_num))
# Out:
# Original Value: 10
# Original Type: <class 'int'>
# After Type Casting: 10.0
# New Type: <class 'float'>

# %%
# String to Integer
age = "22"
print("Original Type:", type(age))
age = int(age)
print("Age:", age)
print("New Type:", type(age))
# Out:
# Original Type: <class 'str'>
# Age: 22
# New Type: <class 'int'>

# %%
# Float to Integer
price = 99.99
print("Original Value:", price)
price = int(price)
print("After Type Casting:", price)
# Out:
# Original Value: 99.99
# After Type Casting: 99

# %%
# Integer to String
marks = 85
print(type(marks))
marks = str(marks)
print(type(marks))
print("Marks:", marks)
# Out:
# <class 'int'>
# <class 'str'>
# Marks: 85
