# %%
# Strings in Puthon
name = "Mian SHAKAR AFZAL"
city = 'Islamabad'
message = "Hello, World!"
print(name)
print(city)
print(message)
# Out:
# Mian SHAKAR AFZAL
# Islamabad
# Hello, World!

# %%
name = "SHAKAR"
print(name)
# Out:
# SHAKAR

# %%
name = 'SHAKAR'
print(name)
# Out:
# SHAKAR

# %%
name = """SHAKAR"""
print(name)
# Out:
# SHAKAR

# %%
word = "Python"
print(word[0])
print(word[1])
print(word[5])
# Out:
# P
# y
# n

# %%
word = "Python"
print(word[-1])
print(word[-2])
# Out:
# n
# o

# %%
text = "Python"
print(len(text))
# Out:
# 6

# %%
word = "Python"
print(word[0:2])
print(word[2:5])
print(word[:4])
print(word[3:])
# Out:
# Py
# tho
# Pyth
# hon

# %%
word = "Python"
print(word[::2])
# Out:
# Pto

# %%
word = "MIAN"
print(word[::-1])
# Out:
# NAIM

# %%
first = "Hello"
second = "World"
print(first + " " + second)
# Out:
# Hello World

# %%
print("MIAN " * 3)
# Out:
# MIAN MIAN MIAN

# %%
text = "Python Programming"
print("Python" in text)
# Out:
# True

# %%
text="C++,C,Pyhton,Java"
print("Java" not in text)
# Out:
# False

# %%
name = "mian"
print(name.upper())
# Out:
# MIAN

# %%
name = "MIAN"
print(name.lower())
# Out:
# mian

# %%
text = "python programming"
print(text.title())
# Out:
# Python Programming

# %%
text = "python programming"
print(text.capitalize())
# Out:
# Python programming

# %%
text = "PyThOn"
print(text.swapcase())
# Out:
# pYtHoN

# %%
text = "   MIAN SHAKAR AFZAL              "
print(text.strip())
# Out:
# MIAN SHAKAR AFZAL

# %%
text = "   MIAN"
print(text.lstrip())
# Out:
# MIAN

# %%
text = "MIAN        "
print(text.rstrip())
# Out:
# MIAN

# %%
text = "I like Python Programming"

print(text.replace("like", "love"))
# Out:
# I love Python Programming

# %%
text = "SHAKAR"
print(text.find("K"))
# Out:
# 3

# %%
text = "Shakar"
print(text.count("a"))
# Out:
# 2

# %%
text = "Python"
print(text.startswith("Py"))
# Out:
# True

# %%
text = "Python"
print(text.endswith("on"))
# Out:
# True

# %%
text = "Python Java C++"
print(text.split())
# Out:
# ['Python', 'Java', 'C++']

# %%
languages = ["Python","Java","C++"]
print("-".join(languages))
# Out:
# Python-Java-C++

# %%
print("MIAN\nSHAKAR")
# Out:
# MIAN
# SHAKAR

# %%
print("Python\tJava")
# Out:
# Python	Java

# %%
print("He said \"Hello\"")
# Out:
# He said "Hello"

# %%
print('It\'s Python')
# Out:
# It's Python

# %%
print("C:\\Users\\Mian")
# Out:
# C:\Users\Mian

# %%
name ="Mian"
age =22
print("Name:", name)
print("Age:", age)
# Out:
# Name: Mian
# Age: 22

# %%
name = "\"Mian SHAKAR AFZAL\""
age = "\"22\""
print("My name is {} and I am {} years old.".format(name, age))
# Out:
# My name is "Mian SHAKAR AFZAL" and I am "22" years old.

# %%
text = input("Enter Name: ")
print(text.upper())
print(text.lower())
print(text.title())
# Out:
# Enter Name: mian shakar afzal
# MIAN SHAKAR AFZAL
# mian shakar afzal
# Mian Shakar Afzal

# %%
text = input("Enter a word: ")
print(text[::-1])
# Out:
# Enter a word: mian
# naim

# %%
word = input("Enter a word: ")
if word == word[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Enter a word: MAAM
# Palindrome

# %%
sentence = input("Enter a sentence: ")
words = sentence.split()
print("Total words:", len(words))
# Out:
# Enter a sentence: Mian Shakar Afzal
# Total words: 3
