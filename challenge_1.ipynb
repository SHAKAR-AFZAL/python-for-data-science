# %%
# PYTHON CHALLENGE QUESTIONS TOPIC-WISE (print())

# %%
print("Name: Mian Shakar Afzal")
print("Age: 22")
print("Country: Pakistan")
print("Career Goal: AI/ML Engineer")
# Out:
# Name: Mian Shakar Afzal
# Age: 22
# Country: Pakistan
# Career Goal: AI/ML Engineer

# %%
print("Name: Mian Shakar")
print("Role: Aspiring Data Analyst")
print("Skills: Python,Excel,SQL")
print("Status: Learning")
# Out:
# Name: Mian Shakar
# Role: Aspiring Data Analyst
# Skills: Python,Excel,SQL
# Status: Learning

# %%
print("Welcome")
print("Mian Shakar Afzal")
print("Computer Science Department")
print("Mian Shakar have successfully joined the company")
# Out:
# Welcome
# Mian Shakar Afzal
# Computer Science Department
# Mian Shakar have successfully joined the company

# %%
print("-----------------------------------")
print("     DATA ANALYTICS SYSTEM")
print("-----------------------------------")
print("1. Sales Analysis")
print("2. Customer Analysis")
print("3. Product Analysis")
print("4. Generate Report")
print("-----------------------------------")
print("        Welcome, Analyst!")
print("-----------------------------------")
# Out:
# -----------------------------------
#      DATA ANALYTICS SYSTEM
# -----------------------------------
# 1. Sales Analysis
# 2. Customer Analysis
# 3. Product Analysis
# 4. Generate Report
# -----------------------------------
#         Welcome, Analyst!
# -----------------------------------

# %%
print("==================================")
print("     SALES ANALYSIS REPORT"       )
print("Company: ABC Store")
print("Period: January 2026")
print("Prepared By: Data Analytics Team")
print("==================================")
# Out:
# ...
#      SALES ANALYSIS REPORT
# Company: ABC Store
# Period: January 2026
# Prepared By: Data Analytics Team
# ...
