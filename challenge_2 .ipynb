# %%
# PYTHON CHALLENGE (TOPIC: COMMENTS)

# Enter Your Name
print("Name: Mian Shakar Afzal")
# Enter Your Age
print("Age: 22")
# Enter The Name Of Your Country
print("Country: Pakistan")
# Enter Your Career Goal
print("Career Goal: AI/ML Engineer")
# Out:
# Name: Mian Shakar Afzal
# Age: 22
# Country: Pakistan
# Career Goal: AI/ML Engineer

# %%
# Student Information
print("Student Information")
print("Name: Mian Shakar")

# Academic Information
print("Program: BSCS")
print("Semester: 6")
print("University: NUTECH")
# Out:
# Student Information
# Name: Mian Shakar
# Program: BSCS
# Semester: 6
# University: NUTECH

# %%
print("Starting Data Analysis")
# print("Loading dataset")
print("Cleaning data")
# print("Generating report")
print("Analysis completed")
# Out:
# Starting Data Analysis
# Cleaning data
# Analysis completed

# %%
# Display project title so report is clearly identified
print("DATA ANALYSIS PROJECT")
# Provide basic project details for tracking work
print("Project: Sales Dashboard")
print("Tool: Python")
# Show the current stage of the project
print("Status: In Progress")
# Out:
# DATA ANALYSIS PROJECT
# Project: Sales Dashboard
# Tool: Python
# Status: In Progress

# %%
# This program displays starting information for a sales analysis project

# Report / Header Section
print("================================")
print("       SALES ANALYSIS")
print("================================")
# Analyst / Project Information Section
print("Dataset: E-Commerce Sales")
print("Analyst: Mian Shakar")
print("Status: Starting Analysis")
print("================================")

# This may be enabled later to display analysis completion date
# print("Analysis Date: January 2026")
# Out:
# ...
#        SALES ANALYSIS
# ...
# Dataset: E-Commerce Sales
# Analyst: Mian Shakar
# Status: Starting Analysis
# ...
